# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('df2.csv', sep=';', index_col='Data', encoding='latin-1')
dataset.head()
# Out:
#                    m0  Saldo empregos  IPCA   Dolar  Aço bruto toneladas  \
# Data
# 31/01/2002  49722.831           44228  0.52  2.4175               2382.4
# 28/02/2002  47891.206           82013  0.36  2.3474               2259.8
# 31/03/2002  48854.685           90260  0.60  2.3228               2409.2
# 30/04/2002  46745.596          175090  0.80  2.3617               2215.3
# 31/05/2002  51513.188          155813  0.21  2.5212               2450.1
#
#             Consumo energia elétrica GWh  \
# Data
# 31/01/2002                         22324
# 28/02/2002                         22695
# 31/03/2002                         23251
# 30/04/2002                         24719
# 31/05/2002                         24728
#
#             Índice Produção bens de consumo média 2012 = 100  \
# Data
# 31/01/2002                                              70.9
# 28/02/2002                                              67.4
# 31/03/2002                                              73.9
# ...

# %%
dataset['m0'].plot()
plt.legend()
plt.show()

dataset['Saldo empregos'].plot()
plt.legend()
plt.show()

dataset['IPCA'].plot()
plt.legend()
plt.show()

dataset['Dolar'].plot()
plt.legend()
plt.show()

dataset['Aço bruto toneladas'].plot()
plt.legend()
plt.show()

dataset['Consumo energia elétrica GWh'].plot()
plt.legend()
plt.show()

dataset['Índice Produção bens de consumo média 2012 = 100'].plot()
plt.legend()
plt.show()

dataset['Produção de cimento qde'].plot()
plt.legend()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(dataset['m0'])
print('=========== M0=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== M0=========== ')

result = adfuller(dataset['Saldo empregos'])
print('=========== Saldo empregos=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Saldo empregos=========== ')

    
result = adfuller(dataset['IPCA'])
print('=========== IPCA=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== IPCA=========== ')

result = adfuller(dataset['Dolar'])
print('=========== Dolar=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Dolar=========== ')

result = adfuller(dataset['Aço bruto toneladas'])
print('=========== Aço bruto toneladas=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Aço bruto toneladas =========== ')

    
result = adfuller(dataset['Consumo energia elétrica GWh'])
print('=========== Consumo energia elétrica GWh =========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Consumo energia elétrica GWh =========== ')

result = adfuller(dataset['Índice Produção bens de consumo média 2012 = 100'])
print('=========== Índice Produção bens de consumo média 2012 = 100 =========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Índice Produção bens de consumo média 2012 = 100 =========== ')

    
result = adfuller(dataset['Produção de cimento qde'])
print('=========== Produção de cimento qde =========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Produção de cimento qde =========== ')
# Out:
# =========== M0===========
# ADF Statistic: 0.208034
# p-value: 0.972709
# Critical Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575
# =========== M0===========
# =========== Saldo empregos===========
# ADF Statistic: -2.198644
# p-value: 0.206738
# Critical Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575
# =========== Saldo empregos===========
# =========== IPCA===========
# ADF Statistic: -3.115523
# p-value: 0.025426
# Critical Values:
# 	1%: -3.464
# 	5%: -2.876
# 	10%: -2.575
# =========== IPCA===========
# =========== Dolar===========
# ADF Statistic: -0.852241
# p-value: 0.803293
# Critical Values:
# 	1%: -3.463
# 	5%: -2.876
# 	10%: -2.574
# =========== Dolar===========
# =========== Aço bruto toneladas===========
# ADF Statistic: -3.892823
# p-value: 0.002088
# Critical Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575
# =========== Aço bruto toneladas ===========
# =========== Consumo energia elétrica GWh ===========
# ADF Statistic: -1.833225
# p-value: 0.364095
# ...

# %%
dataset2 = dataset.diff()
dataset2['IPCA'] = dataset['IPCA']
dataset2['Aço bruto toneladas'] = dataset['Aço bruto toneladas']

dataset2 = dataset2.dropna()

# %%
result = adfuller(dataset2['m0'])
print('=========== M0=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== M0=========== ')

result = adfuller(dataset2['Saldo empregos'])
print('=========== Saldo empregos=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Saldo empregos=========== ')

    
result = adfuller(dataset2['IPCA'])
print('=========== IPCA=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== IPCA=========== ')

result = adfuller(dataset2['Dolar'])
print('=========== Dolar=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Dolar=========== ')

result = adfuller(dataset2['Aço bruto toneladas'])
print('=========== Aço bruto toneladas=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Aço bruto toneladas =========== ')

    
result = adfuller(dataset2['Consumo energia elétrica GWh'])
print('=========== Consumo energia elétrica GWh =========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Consumo energia elétrica GWh =========== ')

result = adfuller(dataset2['Índice Produção bens de consumo média 2012 = 100'])
print('=========== Índice Produção bens de consumo média 2012 = 100 =========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Índice Produção bens de consumo média 2012 = 100 =========== ')

    
result = adfuller(dataset2['Produção de cimento qde'])
print('=========== Produção de cimento qde =========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Produção de cimento qde =========== ')
# Out:
# =========== M0===========
# ADF Statistic: -3.755005
# p-value: 0.003403
# Critical Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575
# =========== M0===========
# =========== Saldo empregos===========
# ADF Statistic: -3.581631
# p-value: 0.006122
# Critical Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575
# =========== Saldo empregos===========
# =========== IPCA===========
# ADF Statistic: -4.229177
# p-value: 0.000588
# Critical Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575
# =========== IPCA===========
# =========== Dolar===========
# ADF Statistic: -15.917612
# p-value: 0.000000
# Critical Values:
# 	1%: -3.463
# 	5%: -2.876
# 	10%: -2.574
# =========== Dolar===========
# =========== Aço bruto toneladas===========
# ADF Statistic: -3.969797
# p-value: 0.001577
# Critical Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575
# =========== Aço bruto toneladas ===========
# =========== Consumo energia elétrica GWh ===========
# ADF Statistic: -4.147939
# p-value: 0.000806
# ...

# %%
dataset2['Produção de cimento qde'] = dataset2['Produção de cimento qde'].diff()
dataset2 = dataset2.dropna()

result = adfuller(dataset2['m0'])
print('=========== M0=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== M0=========== ')

result = adfuller(dataset2['Saldo empregos'])
print('=========== Saldo empregos=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Saldo empregos=========== ')

    
result = adfuller(dataset2['IPCA'])
print('=========== IPCA=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== IPCA=========== ')

result = adfuller(dataset2['Dolar'])
print('=========== Dolar=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Dolar=========== ')

result = adfuller(dataset2['Aço bruto toneladas'])
print('=========== Aço bruto toneladas=========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Aço bruto toneladas =========== ')

    
result = adfuller(dataset2['Consumo energia elétrica GWh'])
print('=========== Consumo energia elétrica GWh =========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Consumo energia elétrica GWh =========== ')

result = adfuller(dataset2['Índice Produção bens de consumo média 2012 = 100'])
print('=========== Índice Produção bens de consumo média 2012 = 100 =========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Índice Produção bens de consumo média 2012 = 100 =========== ')

    
result = adfuller(dataset2['Produção de cimento qde'])
print('=========== Produção de cimento qde =========== ')
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
print('=========== Produção de cimento qde =========== ')
# Out:
# =========== M0===========
# ADF Statistic: -3.765612
# p-value: 0.003279
# Critical Values:
# 	1%: -3.466
# 	5%: -2.877
# 	10%: -2.575
# =========== M0===========
# =========== Saldo empregos===========
# ADF Statistic: -3.581742
# p-value: 0.006120
# Critical Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575
# =========== Saldo empregos===========
# =========== IPCA===========
# ADF Statistic: -4.168074
# p-value: 0.000746
# Critical Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575
# =========== IPCA===========
# =========== Dolar===========
# ADF Statistic: -15.880522
# p-value: 0.000000
# Critical Values:
# 	1%: -3.463
# 	5%: -2.876
# 	10%: -2.574
# =========== Dolar===========
# =========== Aço bruto toneladas===========
# ADF Statistic: -3.878483
# p-value: 0.002199
# Critical Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575
# =========== Aço bruto toneladas ===========
# =========== Consumo energia elétrica GWh ===========
# ADF Statistic: -4.115649
# p-value: 0.000912
# ...

# %%
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=12
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

grangers_causation_matrix(dataset, variables = dataset.columns)
# Out:
#                                                       m0_x  Saldo empregos_x  \
# m0_y                                                1.0000            0.0000
# Saldo empregos_y                                    0.0000            1.0000
# IPCA_y                                              0.0072            0.0092
# Dolar_y                                             0.0002            0.0243
# Aço bruto toneladas_y                               0.0000            0.0000
# Consumo energia elétrica GWh_y                      0.0000            0.0000
# Índice Produção bens de consumo média 2012 = 100_y  0.0000            0.0000
# Produção de cimento qde_y                           0.0000            0.0000
#
#                                                     IPCA_x  Dolar_x  \
# m0_y                                                0.0023   0.0240
# Saldo empregos_y                                    0.0166   0.0000
# IPCA_y                                              1.0000   0.0000
# ...

# %%
from statsmodels.tsa.api import VAR, DynamicVAR
from sklearn.linear_model import LinearRegression

# %%
for i in range(dataset2.shape[1]):
    dataset2.iloc[:,i:(i+1)].plot.hist()
    plt.legend()
    plt.title(dataset2.columns[i])
    plt.show()

# %%
cut = int(dataset2.shape[0] * 0.7)
treino = dataset2[:cut]
teste  = dataset2[cut:]

# %%
treino.tail()
# Out:
#                    m0  Saldo empregos  IPCA   Dolar  Aço bruto toneladas  \
# Data
# 31/07/2013  -4096.038        -82373.0  0.03  0.0747               2925.8
# 31/08/2013   -863.350         86185.0  0.24  0.0822               3001.9
# 30/09/2013  19966.724         83420.0  0.35 -0.1425               2974.8
# 31/10/2013 -18439.761       -116175.0  0.57 -0.0274               2977.7
# 30/11/2013   4411.721        -47407.0  0.54  0.1223               2707.2
#
#             Consumo energia elétrica GWh  \
# Data
# 31/07/2013                          70.0
# 31/08/2013                         916.0
# 30/09/2013                         -89.0
# 31/10/2013                         864.0
# 30/11/2013                         532.0
#
#             Índice Produção bens de consumo média 2012 = 100  \
# Data
# 31/07/2013                                               5.5
# 31/08/2013                                               6.1
# 30/09/2013                                              -3.2
# ...

# %%
model = VAR(treino)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)

# %%
for i in range(1,6):
    result = model.fit(i)
    print('=============== Order ',i,'=====================')
    print('AIC =', result.aic)
    print('BIC =', result.bic)
    print('===========================')
# Out:
# =============== Order  1 =====================
# AIC = 86.18450607114296
# BIC = 87.69735074562774
# ...
# =============== Order  2 =====================
# AIC = 85.00255681077923
# BIC = 87.87369677413011
# ...
# =============== Order  3 =====================
# AIC = 84.46237793000165
# BIC = 88.70477457515702
# ...
# =============== Order  4 =====================
# AIC = 83.82065311315861
# BIC = 89.44747767095879
# ...
# =============== Order  5 =====================
# AIC = 83.4432217559782
# BIC = 90.4678600098122
# ...

# %%
result = model.fit(5)
print(result.summary())
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 01, Sep, 2019
# Time:                     21:14:07
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                    90.4679
# Nobs:                     136.000    HQIC:                   86.2979
# Log likelihood:          -6889.94    FPE:                2.02347e+36
# AIC:                      83.4432    Det(Omega_mle):     2.45822e+35
# --------------------------------------------------------------------
# Results for equation m0
# ...
#                                                          coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------------------
# const                                                    2217.273715      6138.073656            0.361           0.718
# ...

# %%
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(result.resid)
out

for i in range(dataset2.shape[1]):
    print(dataset2.columns[i],'......',out[i])
# Out:
# m0 ...... 1.8242118624267378
# Saldo empregos ...... 1.9202715263785315
# IPCA ...... 1.8232174474088745
# Dolar ...... 1.7916091704622699
# Aço bruto toneladas ...... 1.9620018862396027
# Consumo energia elétrica GWh ...... 2.045195107965046
# Índice Produção bens de consumo média 2012 = 100 ...... 1.8299890558579774
# Produção de cimento qde ...... 1.990465240523207

# %%
irf = result.irf(periods=24)

# %%
irf.plot(orth=False, impulse='m0')
plt.show()
